# %% [markdown]
# # Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data/dataset_train.csv')
df
# Out:
#       Index Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0         0      Ravenclaw     Tamara          Hsu  2000-03-30      Left
# 1         1      Slytherin      Erich      Paredes  1999-10-14     Right
# 2         2      Ravenclaw   Stephany        Braun  1999-11-03      Left
# 3         3     Gryffindor      Vesta    Mcmichael  2000-08-19      Left
# 4         4     Gryffindor     Gaston        Gibbs  1998-09-27      Left
# ...     ...            ...        ...          ...         ...       ...
# 1595   1595     Gryffindor       Jung        Blank  2001-09-14     Right
# 1596   1596      Slytherin     Shelli         Lock  1998-03-12      Left
# 1597   1597     Gryffindor   Benjamin  Christensen  1999-10-24     Right
# 1598   1598     Hufflepuff  Charlotte       Dillon  2001-09-21      Left
# 1599   1599     Hufflepuff      Kylie        Nowak  2000-08-21      Left
#
#       Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# ...

# %% [markdown]
# # Data histogram
# Answer this question : Which Hogwarts course has a homogeneous score distribution between all four houses?

# %% [markdown]
# ## Group data

# %%
group_house = df.groupby('Hogwarts House')

# %% [markdown]
# ## Course

# %%
courses = []
for series_name, series in df.items():
    if series.dtype == 'float64':
        courses.append(series_name)
courses
# Out:
# ['Arithmancy',
#  'Astronomy',
#  'Herbology',
#  'Defense Against the Dark Arts',
#  'Divination',
#  'Muggle Studies',
#  'Ancient Runes',
#  'History of Magic',
#  'Transfiguration',
#  'Potions',
#  'Care of Magical Creatures',
#  'Charms',
#  'Flying']

# %% [markdown]
# ## Histogram

# %%
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)
plt.figure(figsize=(20,15))
for i, course in enumerate(courses, 1):
    plt.subplot(4, 4, i)
    color_each_house = {'Ravenclaw': 'blue', 'Slytherin': 'green', 'Gryffindor': 'red', 'Hufflepuff': 'yellow'}
    for house in df['Hogwarts House'].unique():
        subset = df[df['Hogwarts House'] == house]
        sns.histplot(subset[course], kde=True, label=house)
    plt.xlabel('Valeurs')
    plt.ylabel('Fréquence')
    plt.title(course)
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# On voit bien que "care of magical creatures" et "arithmancy" sont les datas les plus homogènes car elles se superposent l'un de l'autre
